# %%
# demo of cvtransformer on simple oscillator data set

# identical to v1 demo but uses the v2 model which has:
# 1) more efficient forward pass
# 2) potential for extra numeric head blocks to allow for increased numeric expressiveness

# the extra expressiveness does not provide benefit in this small case where vocab is so small

# %%
import torch   
import yaml
import numpy as np
import matplotlib.pyplot as plt
import time
import dataclasses

from multivariategpt import GPTV2, GPTConfigV2

# %%
# initialize model from config. 
# V2 with n_head_blocks==0 is identical in parameter count with v1

config_path = "./cv_demo.yaml"  # replace with actual path
with open(config_path, "r") as f:
    config_yaml = yaml.safe_load(f)
config = config_yaml['model']
# config['n]

model = GPTV2(GPTConfigV2(**config))
n_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {n_params}")
# Out:
# Number of parameters: 15552

# %%
# will re-initialize with 1 block just to show the difference
config_path = "./cv_demo.yaml"  # replace with actual path
with open(config_path, "r") as f:
    config_yaml = yaml.safe_load(f)
config = config_yaml['model']
config['n_head_blocks']=1

model = GPTV2(GPTConfigV2(**config))
n_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {n_params}")
# Out:
# Number of parameters: 22608

# %%
# now we will train this model on the oscillator task from multivariate gpt
# the model is trained on trajectories of simple harmonic oscillators.
#  - each trajectory has [coefficient, position1, position2,...]
#  - the model is trained on 9 different coefficients and tested on 2 held out coefficients


data = torch.load('./multi_oscillator_full_data.pt',weights_only=False)
c_full, v_full, c_t_full, v_t_full, t = data

# remove the held out trajectories
c     = np.delete(c_full, 0, axis=0)
v     = np.delete(v_full, 0, axis=0)
c_t   = np.delete(c_t_full, 0, axis=0)
v_t   = np.delete(v_t_full, 0, axis=0)

c     = np.delete(c, 3, axis=0)
v     = np.delete(v, 3, axis=0)
c_t   = np.delete(c_t, 3, axis=0)
v_t   = np.delete(v_t, 3, axis=0)

# plot the training trajectories
for i in range(9):
    plt.plot(t[:-1],v[i][1:].detach().numpy())

# %%
# fit the model with a simple training loop

# you will see the loss go negative:
#  - cross entropy loss is on a discrete distribution which is a probability mass function. the negative log likelihood is lower bounded by 0
#  - the value loss is from gaussian which is a probablity density function. the negative log likelihood is unbounded below and can go negative

# for this simple example we keep variance fixed for the first 2000 iterations so the model learns to shift the mean correctly first
# in larger more diverse data sets this is not necessary

# it is critcal, however, to center and scale numeric values because on intit, the model estimate mean 0 and variance 1 for all outputs
# any far-away targets can lead to the model just learning to increase variance to reduce loss rather than learning to predict the mean correctly

optimizer = torch.optim.AdamW(model.parameters(), lr=config['learning_rate'],weight_decay=config['weight_decay'])
max_iters = config['max_iters']
iter = 0


scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=max_iters, eta_min=1e-6
)

t0 = time.time()
t0_global = t0
B, T = c.shape

while iter < max_iters:
    x_c, x_v_l, x_v_s, c_loss, v_loss, loss = model(c, v, c_t, v_t)

    # start learning variance after iteration 2000
    if iter > 2000 and model.fit_scale is False:
        model.fit_scale = True

    t1 = time.time()
    dt = t1 - t0
    t0 = t1
    if iter % 100 == 0:
        current_lr = scheduler.get_last_lr()[0]
        print(f"iter (global) {iter}: | train loss {loss:.4f} | val loss {'na'} | "
              f"dt {dt*1000:.2f}ms | tok/sec {B*T/dt:.2f} | lr {current_lr:.2e}")

    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
    scheduler.step()  # update learning rate
    iter += 1

print(f"Total training time: {time.time() - t0_global:.1f}s")
# Out:
# iter (global) 0: | train loss 2.3604 | val loss na | dt 3.00ms | tok/sec 150142.14 | lr 1.00e-04
# iter (global) 100: | train loss 1.9620 | val loss na | dt 6.18ms | tok/sec 72789.70 | lr 1.00e-04
# iter (global) 200: | train loss 1.8559 | val loss na | dt 6.10ms | tok/sec 73782.76 | lr 1.00e-04
# iter (global) 300: | train loss 1.7768 | val loss na | dt 6.41ms | tok/sec 70214.53 | lr 9.99e-05
# iter (global) 400: | train loss 1.7290 | val loss na | dt 6.50ms | tok/sec 69179.96 | lr 9.99e-05
# iter (global) 500: | train loss 1.6993 | val loss na | dt 6.67ms | tok/sec 67427.72 | lr 9.98e-05
# iter (global) 600: | train loss 1.6791 | val loss na | dt 6.61ms | tok/sec 68069.71 | lr 9.98e-05
# iter (global) 700: | train loss 1.6650 | val loss na | dt 6.21ms | tok/sec 72498.92 | lr 9.97e-05
# iter (global) 800: | train loss 1.6547 | val loss na | dt 6.27ms | tok/sec 71765.66 | lr 9.96e-05
# iter (global) 900: | train loss 1.6470 | val loss na | dt 6.81ms | tok/sec 66040.48 | lr 9.95e-05
# iter (global) 1000: | train loss 1.6412 | val loss na | dt 6.22ms | tok/sec 72312.82 | lr 9.94e-05
# iter (global) 1100: | train loss 1.6366 | val loss na | dt 6.61ms | tok/sec 68091.81 | lr 9.93e-05
# iter (global) 1200: | train loss 1.6330 | val loss na | dt 11.12ms | tok/sec 40456.92 | lr 9.91e-05
# iter (global) 1300: | train loss 1.6302 | val loss na | dt 7.30ms | tok/sec 61620.53 | lr 9.90e-05
# iter (global) 1400: | train loss 1.6280 | val loss na | dt 6.60ms | tok/sec 68150.81 | lr 9.88e-05
# iter (global) 1500: | train loss 1.6258 | val loss na | dt 6.68ms | tok/sec 67365.15 | lr 9.86e-05
# iter (global) 1600: | train loss 1.6242 | val loss na | dt 6.28ms | tok/sec 71700.23 | lr 9.84e-05
# iter (global) 1700: | train loss 1.6228 | val loss na | dt 6.70ms | tok/sec 67206.84 | lr 9.82e-05
# iter (global) 1800: | train loss 1.6217 | val loss na | dt 6.52ms | tok/sec 68977.70 | lr 9.80e-05
# iter (global) 1900: | train loss 1.6207 | val loss na | dt 6.48ms | tok/sec 69462.56 | lr 9.78e-05
# iter (global) 2000: | train loss 1.6198 | val loss na | dt 6.50ms | tok/sec 69210.40 | lr 9.76e-05
# iter (global) 2100: | train loss 0.1860 | val loss na | dt 6.37ms | tok/sec 70632.32 | lr 9.73e-05
# iter (global) 2200: | train loss -0.1385 | val loss na | dt 6.31ms | tok/sec 71337.09 | lr 9.71e-05
# iter (global) 2300: | train loss -0.5049 | val loss na | dt 6.49ms | tok/sec 69317.15 | lr 9.68e-05
# iter (global) 2400: | train loss -0.8881 | val loss na | dt 6.63ms | tok/sec 67851.92 | lr 9.65e-05
# iter (global) 2500: | train loss -1.2814 | val loss na | dt 6.36ms | tok/sec 70778.00 | lr 9.62e-05
# iter (global) 2600: | train loss -1.6702 | val loss na | dt 6.15ms | tok/sec 73147.96 | lr 9.59e-05
# iter (global) 2700: | train loss -1.8517 | val loss na | dt 6.61ms | tok/sec 68079.53 | lr 9.56e-05
# iter (global) 2800: | train loss -2.3893 | val loss na | dt 7.08ms | tok/sec 63577.89 | lr 9.53e-05
# iter (global) 2900: | train loss -2.7151 | val loss na | dt 6.87ms | tok/sec 65540.55 | lr 9.50e-05
# iter (global) 3000: | train loss -2.9538 | val loss na | dt 7.06ms | tok/sec 63777.68 | lr 9.46e-05
# iter (global) 3100: | train loss -3.1007 | val loss na | dt 7.14ms | tok/sec 63053.28 | lr 9.42e-05
# iter (global) 3200: | train loss -1.8331 | val loss na | dt 6.62ms | tok/sec 67947.18 | lr 9.39e-05
# iter (global) 3300: | train loss -3.5290 | val loss na | dt 6.36ms | tok/sec 70711.70 | lr 9.35e-05
# iter (global) 3400: | train loss -3.4977 | val loss na | dt 6.54ms | tok/sec 68806.71 | lr 9.31e-05
# iter (global) 3500: | train loss -3.7356 | val loss na | dt 6.54ms | tok/sec 68816.74 | lr 9.27e-05
# iter (global) 3600: | train loss -3.6244 | val loss na | dt 6.52ms | tok/sec 69005.44 | lr 9.23e-05
# iter (global) 3700: | train loss -3.7964 | val loss na | dt 7.06ms | tok/sec 63702.35 | lr 9.19e-05
# iter (global) 3800: | train loss -3.9303 | val loss na | dt 6.45ms | tok/sec 69809.40 | lr 9.14e-05
# iter (global) 3900: | train loss -4.0621 | val loss na | dt 7.34ms | tok/sec 61292.36 | lr 9.10e-05
# iter (global) 4000: | train loss -3.9770 | val loss na | dt 6.38ms | tok/sec 70500.40 | lr 9.05e-05
# iter (global) 4100: | train loss -4.0960 | val loss na | dt 6.93ms | tok/sec 64972.01 | lr 9.01e-05
# iter (global) 4200: | train loss -4.2110 | val loss na | dt 6.53ms | tok/sec 68879.53 | lr 8.96e-05
# iter (global) 4300: | train loss -4.1068 | val loss na | dt 6.84ms | tok/sec 65771.22 | lr 8.91e-05
# iter (global) 4400: | train loss -4.2112 | val loss na | dt 6.40ms | tok/sec 70269.43 | lr 8.86e-05
# iter (global) 4500: | train loss -4.3104 | val loss na | dt 6.51ms | tok/sec 69121.69 | lr 8.81e-05
# iter (global) 4600: | train loss -4.1894 | val loss na | dt 6.39ms | tok/sec 70389.98 | lr 8.76e-05
# iter (global) 4700: | train loss -4.3111 | val loss na | dt 6.55ms | tok/sec 68714.02 | lr 8.71e-05
# iter (global) 4800: | train loss -4.4021 | val loss na | dt 6.36ms | tok/sec 70722.30 | lr 8.66e-05
# iter (global) 4900: | train loss -3.9944 | val loss na | dt 6.83ms | tok/sec 65925.14 | lr 8.60e-05
# iter (global) 5000: | train loss -4.3705 | val loss na | dt 6.09ms | tok/sec 73843.38 | lr 8.55e-05
# iter (global) 5100: | train loss -4.4522 | val loss na | dt 6.41ms | tok/sec 70238.05 | lr 8.49e-05
# iter (global) 5200: | train loss -4.5319 | val loss na | dt 6.57ms | tok/sec 68474.71 | lr 8.44e-05
# iter (global) 5300: | train loss -4.3676 | val loss na | dt 6.64ms | tok/sec 67790.99 | lr 8.38e-05
# iter (global) 5400: | train loss -4.4639 | val loss na | dt 6.46ms | tok/sec 69639.41 | lr 8.32e-05
# iter (global) 5500: | train loss -4.5335 | val loss na | dt 6.45ms | tok/sec 69809.40 | lr 8.26e-05
# iter (global) 5600: | train loss -4.6016 | val loss na | dt 6.69ms | tok/sec 67245.15 | lr 8.21e-05
# iter (global) 5700: | train loss -2.4530 | val loss na | dt 6.58ms | tok/sec 68380.44 | lr 8.14e-05
# iter (global) 5800: | train loss -4.5601 | val loss na | dt 6.67ms | tok/sec 67427.72 | lr 8.08e-05
# iter (global) 5900: | train loss -4.6258 | val loss na | dt 7.32ms | tok/sec 61484.03 | lr 8.02e-05
# iter (global) 6000: | train loss -4.6901 | val loss na | dt 6.73ms | tok/sec 66894.80 | lr 7.96e-05
# iter (global) 6100: | train loss -1.3793 | val loss na | dt 6.91ms | tok/sec 65122.20 | lr 7.90e-05
# iter (global) 6200: | train loss -4.5941 | val loss na | dt 6.65ms | tok/sec 67640.37 | lr 7.83e-05
# iter (global) 6300: | train loss -4.6512 | val loss na | dt 6.83ms | tok/sec 65840.05 | lr 7.77e-05
# iter (global) 6400: | train loss -4.7059 | val loss na | dt 7.53ms | tok/sec 59768.73 | lr 7.70e-05
# iter (global) 6500: | train loss -4.7600 | val loss na | dt 7.23ms | tok/sec 62266.98 | lr 7.64e-05
# iter (global) 6600: | train loss -4.8144 | val loss na | dt 7.06ms | tok/sec 63704.50 | lr 7.57e-05
# iter (global) 6700: | train loss -4.6996 | val loss na | dt 6.74ms | tok/sec 66776.47 | lr 7.50e-05
# iter (global) 6800: | train loss -4.7555 | val loss na | dt 6.95ms | tok/sec 64764.67 | lr 7.43e-05
# iter (global) 6900: | train loss -4.8079 | val loss na | dt 6.81ms | tok/sec 66098.29 | lr 7.37e-05
# iter (global) 7000: | train loss -4.8600 | val loss na | dt 6.65ms | tok/sec 67698.59 | lr 7.30e-05
# iter (global) 7100: | train loss -4.5693 | val loss na | dt 6.49ms | tok/sec 69306.97 | lr 7.23e-05
# iter (global) 7200: | train loss -4.8233 | val loss na | dt 6.70ms | tok/sec 67142.29 | lr 7.16e-05
# iter (global) 7300: | train loss -4.8750 | val loss na | dt 6.94ms | tok/sec 64871.52 | lr 7.09e-05
# iter (global) 7400: | train loss -4.9263 | val loss na | dt 6.85ms | tok/sec 65675.10 | lr 7.02e-05
# iter (global) 7500: | train loss -4.6965 | val loss na | dt 6.18ms | tok/sec 72758.83 | lr 6.94e-05
# iter (global) 7600: | train loss -4.8749 | val loss na | dt 7.57ms | tok/sec 59459.94 | lr 6.87e-05
# iter (global) 7700: | train loss -4.9243 | val loss na | dt 6.60ms | tok/sec 68138.51 | lr 6.80e-05
# iter (global) 7800: | train loss -4.9730 | val loss na | dt 6.31ms | tok/sec 71302.06 | lr 6.73e-05
# iter (global) 7900: | train loss 0.4544 | val loss na | dt 6.82ms | tok/sec 65941.26 | lr 6.65e-05
# iter (global) 8000: | train loss -4.9299 | val loss na | dt 6.38ms | tok/sec 70489.87 | lr 6.58e-05
# iter (global) 8100: | train loss -4.9777 | val loss na | dt 6.26ms | tok/sec 71932.50 | lr 6.51e-05
# iter (global) 8200: | train loss -5.0245 | val loss na | dt 6.63ms | tok/sec 67832.41 | lr 6.43e-05
# iter (global) 8300: | train loss -5.0711 | val loss na | dt 6.32ms | tok/sec 71159.58 | lr 6.36e-05
# iter (global) 8400: | train loss -4.9783 | val loss na | dt 6.44ms | tok/sec 69910.25 | lr 6.28e-05
# iter (global) 8500: | train loss -5.0258 | val loss na | dt 6.42ms | tok/sec 70047.76 | lr 6.21e-05
# iter (global) 8600: | train loss -5.0701 | val loss na | dt 6.40ms | tok/sec 70332.27 | lr 6.13e-05
# iter (global) 8700: | train loss -5.1141 | val loss na | dt 6.40ms | tok/sec 70277.28 | lr 6.05e-05
# iter (global) 8800: | train loss -5.0386 | val loss na | dt 6.40ms | tok/sec 70290.36 | lr 5.98e-05
# iter (global) 8900: | train loss -5.0974 | val loss na | dt 6.49ms | tok/sec 69294.25 | lr 5.90e-05
# iter (global) 9000: | train loss -5.1413 | val loss na | dt 6.45ms | tok/sec 69744.91 | lr 5.82e-05
# iter (global) 9100: | train loss -4.3659 | val loss na | dt 6.27ms | tok/sec 71806.61 | lr 5.75e-05
# iter (global) 9200: | train loss -5.1233 | val loss na | dt 6.37ms | tok/sec 70645.54 | lr 5.67e-05
# iter (global) 9300: | train loss -5.1668 | val loss na | dt 7.19ms | tok/sec 62620.24 | lr 5.59e-05
# iter (global) 9400: | train loss -5.2095 | val loss na | dt 6.65ms | tok/sec 67628.25 | lr 5.52e-05
# iter (global) 9500: | train loss -5.1440 | val loss na | dt 6.95ms | tok/sec 64784.68 | lr 5.44e-05
# iter (global) 9600: | train loss -5.1816 | val loss na | dt 7.22ms | tok/sec 62369.86 | lr 5.36e-05
# iter (global) 9700: | train loss -5.2222 | val loss na | dt 6.66ms | tok/sec 67516.97 | lr 5.28e-05
# iter (global) 9800: | train loss -5.2624 | val loss na | dt 6.54ms | tok/sec 68776.62 | lr 5.21e-05
# iter (global) 9900: | train loss -4.6979 | val loss na | dt 6.64ms | tok/sec 67720.45 | lr 5.13e-05
# iter (global) 10000: | train loss -5.2476 | val loss na | dt 6.49ms | tok/sec 69294.25 | lr 5.05e-05
# iter (global) 10100: | train loss -5.2866 | val loss na | dt 6.73ms | tok/sec 66833.21 | lr 4.97e-05
# iter (global) 10200: | train loss -5.3252 | val loss na | dt 6.28ms | tok/sec 71610.46 | lr 4.89e-05
# iter (global) 10300: | train loss -5.2137 | val loss na | dt 7.03ms | tok/sec 63974.40 | lr 4.82e-05
# iter (global) 10400: | train loss -5.2998 | val loss na | dt 6.33ms | tok/sec 71135.45 | lr 4.74e-05
# iter (global) 10500: | train loss -5.3357 | val loss na | dt 6.49ms | tok/sec 69380.86 | lr 4.66e-05
# iter (global) 10600: | train loss -5.3715 | val loss na | dt 23.73ms | tok/sec 18967.31 | lr 4.58e-05
# iter (global) 10700: | train loss -5.3386 | val loss na | dt 7.43ms | tok/sec 60541.34 | lr 4.51e-05
# iter (global) 10800: | train loss -5.3557 | val loss na | dt 6.81ms | tok/sec 66031.23 | lr 4.43e-05
# iter (global) 10900: | train loss -5.3895 | val loss na | dt 6.46ms | tok/sec 69634.27 | lr 4.35e-05
# iter (global) 11000: | train loss -5.4232 | val loss na | dt 6.60ms | tok/sec 68150.81 | lr 4.28e-05
# iter (global) 11100: | train loss -5.1624 | val loss na | dt 6.57ms | tok/sec 68502.04 | lr 4.20e-05
# iter (global) 11200: | train loss -5.4001 | val loss na | dt 6.41ms | tok/sec 70235.43 | lr 4.12e-05
# iter (global) 11300: | train loss -5.4309 | val loss na | dt 8.54ms | tok/sec 52692.26 | lr 4.05e-05
# iter (global) 11400: | train loss -5.4614 | val loss na | dt 6.43ms | tok/sec 70006.19 | lr 3.97e-05
# iter (global) 11500: | train loss -5.4920 | val loss na | dt 6.46ms | tok/sec 69683.11 | lr 3.89e-05
# iter (global) 11600: | train loss -5.2800 | val loss na | dt 6.60ms | tok/sec 68202.53 | lr 3.82e-05
# iter (global) 11700: | train loss -5.5005 | val loss na | dt 6.40ms | tok/sec 70348.00 | lr 3.74e-05
# iter (global) 11800: | train loss -5.5308 | val loss na | dt 6.60ms | tok/sec 68140.97 | lr 3.67e-05
# iter (global) 11900: | train loss -5.3228 | val loss na | dt 7.28ms | tok/sec 61812.24 | lr 3.59e-05
# iter (global) 12000: | train loss -5.5422 | val loss na | dt 6.61ms | tok/sec 68079.53 | lr 3.52e-05
# iter (global) 12100: | train loss -5.5720 | val loss na | dt 6.22ms | tok/sec 72290.66 | lr 3.45e-05
# iter (global) 12200: | train loss -4.8248 | val loss na | dt 6.20ms | tok/sec 72627.24 | lr 3.37e-05
# iter (global) 12300: | train loss -5.5828 | val loss na | dt 6.16ms | tok/sec 73023.44 | lr 3.30e-05
# iter (global) 12400: | train loss -5.6117 | val loss na | dt 6.65ms | tok/sec 67688.88 | lr 3.23e-05
# iter (global) 12500: | train loss -5.6404 | val loss na | dt 6.43ms | tok/sec 69975.04 | lr 3.16e-05
# iter (global) 12600: | train loss -5.6200 | val loss na | dt 6.32ms | tok/sec 71191.79 | lr 3.08e-05
# iter (global) 12700: | train loss -5.6514 | val loss na | dt 6.15ms | tok/sec 73196.18 | lr 3.01e-05
# iter (global) 12800: | train loss -5.6788 | val loss na | dt 6.50ms | tok/sec 69273.90 | lr 2.94e-05
# iter (global) 12900: | train loss -5.4342 | val loss na | dt 6.31ms | tok/sec 71315.53 | lr 2.87e-05
# iter (global) 13000: | train loss -5.6955 | val loss na | dt 6.39ms | tok/sec 70410.98 | lr 2.80e-05
# iter (global) 13100: | train loss -5.7219 | val loss na | dt 6.26ms | tok/sec 71874.97 | lr 2.73e-05
# iter (global) 13200: | train loss -4.8713 | val loss na | dt 6.45ms | tok/sec 69814.57 | lr 2.67e-05
# iter (global) 13300: | train loss -5.7387 | val loss na | dt 6.39ms | tok/sec 70466.19 | lr 2.60e-05
# iter (global) 13400: | train loss -5.7639 | val loss na | dt 6.39ms | tok/sec 70387.35 | lr 2.53e-05
# iter (global) 13500: | train loss -5.7525 | val loss na | dt 6.44ms | tok/sec 69876.60 | lr 2.46e-05
# iter (global) 13600: | train loss -5.7832 | val loss na | dt 6.48ms | tok/sec 69485.58 | lr 2.40e-05
# iter (global) 13700: | train loss -5.8075 | val loss na | dt 6.80ms | tok/sec 66207.27 | lr 2.33e-05
# iter (global) 13800: | train loss -5.8313 | val loss na | dt 6.88ms | tok/sec 65386.16 | lr 2.27e-05
# iter (global) 13900: | train loss -5.8186 | val loss na | dt 6.65ms | tok/sec 67645.22 | lr 2.20e-05
# iter (global) 14000: | train loss -5.8409 | val loss na | dt 6.44ms | tok/sec 69853.32 | lr 2.14e-05
# iter (global) 14100: | train loss -5.8622 | val loss na | dt 7.15ms | tok/sec 62954.43 | lr 2.08e-05
# iter (global) 14200: | train loss -5.8835 | val loss na | dt 6.54ms | tok/sec 68756.58 | lr 2.02e-05
# iter (global) 14300: | train loss -5.8756 | val loss na | dt 6.44ms | tok/sec 69907.66 | lr 1.96e-05
# iter (global) 14400: | train loss -5.9065 | val loss na | dt 6.41ms | tok/sec 70204.08 | lr 1.89e-05
# iter (global) 14500: | train loss -5.9269 | val loss na | dt 6.36ms | tok/sec 70801.89 | lr 1.84e-05
# iter (global) 14600: | train loss -5.8978 | val loss na | dt 6.59ms | tok/sec 68316.09 | lr 1.78e-05
# iter (global) 14700: | train loss -5.9508 | val loss na | dt 6.71ms | tok/sec 67032.60 | lr 1.72e-05
# iter (global) 14800: | train loss -5.9703 | val loss na | dt 6.45ms | tok/sec 69744.91 | lr 1.66e-05
# iter (global) 14900: | train loss -5.9217 | val loss na | dt 6.64ms | tok/sec 67742.33 | lr 1.61e-05
# iter (global) 15000: | train loss -5.9916 | val loss na | dt 6.59ms | tok/sec 68313.61 | lr 1.55e-05
# iter (global) 15100: | train loss -6.0097 | val loss na | dt 6.44ms | tok/sec 69918.01 | lr 1.50e-05
# iter (global) 15200: | train loss -6.0276 | val loss na | dt 6.32ms | tok/sec 71191.79 | lr 1.44e-05
# iter (global) 15300: | train loss -6.0303 | val loss na | dt 6.75ms | tok/sec 66703.31 | lr 1.39e-05
# iter (global) 15400: | train loss -6.0469 | val loss na | dt 6.97ms | tok/sec 64571.91 | lr 1.34e-05
# iter (global) 15500: | train loss -6.0632 | val loss na | dt 6.55ms | tok/sec 68701.52 | lr 1.29e-05
# iter (global) 15600: | train loss -6.0793 | val loss na | dt 6.80ms | tok/sec 66146.94 | lr 1.24e-05
# iter (global) 15700: | train loss -6.0808 | val loss na | dt 6.55ms | tok/sec 68734.04 | lr 1.19e-05
# iter (global) 15800: | train loss -6.1020 | val loss na | dt 7.23ms | tok/sec 62213.62 | lr 1.14e-05
# iter (global) 15900: | train loss -6.1169 | val loss na | dt 6.52ms | tok/sec 68977.70 | lr 1.09e-05
# iter (global) 16000: | train loss -6.1307 | val loss na | dt 6.48ms | tok/sec 69454.90 | lr 1.05e-05
# iter (global) 16100: | train loss -6.1408 | val loss na | dt 6.09ms | tok/sec 73866.50 | lr 1.00e-05
# iter (global) 16200: | train loss -6.1547 | val loss na | dt 6.33ms | tok/sec 71057.78 | lr 9.56e-06
# iter (global) 16300: | train loss -6.1683 | val loss na | dt 6.29ms | tok/sec 71520.91 | lr 9.13e-06
# iter (global) 16400: | train loss -6.1725 | val loss na | dt 6.38ms | tok/sec 70479.34 | lr 8.71e-06
# iter (global) 16500: | train loss -6.1907 | val loss na | dt 6.65ms | tok/sec 67691.31 | lr 8.29e-06
# iter (global) 16600: | train loss -6.2031 | val loss na | dt 6.48ms | tok/sec 69475.35 | lr 7.89e-06
# iter (global) 16700: | train loss -6.2152 | val loss na | dt 6.35ms | tok/sec 70852.39 | lr 7.50e-06
# iter (global) 16800: | train loss -6.2251 | val loss na | dt 6.26ms | tok/sec 71850.35 | lr 7.12e-06
# iter (global) 16900: | train loss -6.2367 | val loss na | dt 6.74ms | tok/sec 66764.66 | lr 6.75e-06
# iter (global) 17000: | train loss -6.2478 | val loss na | dt 6.92ms | tok/sec 65010.05 | lr 6.40e-06
# iter (global) 17100: | train loss -6.2456 | val loss na | dt 6.72ms | tok/sec 66916.15 | lr 6.05e-06
# iter (global) 17200: | train loss -6.2680 | val loss na | dt 6.56ms | tok/sec 68596.65 | lr 5.71e-06
# iter (global) 17300: | train loss -6.2781 | val loss na | dt 6.55ms | tok/sec 68711.52 | lr 5.39e-06
# iter (global) 17400: | train loss -6.2879 | val loss na | dt 6.24ms | tok/sec 72078.09 | lr 5.07e-06
# iter (global) 17500: | train loss -6.2974 | val loss na | dt 6.44ms | tok/sec 69822.31 | lr 4.77e-06
# iter (global) 17600: | train loss -6.3062 | val loss na | dt 6.69ms | tok/sec 67295.50 | lr 4.48e-06
# iter (global) 17700: | train loss -6.3150 | val loss na | dt 6.44ms | tok/sec 69876.60 | lr 4.20e-06
# iter (global) 17800: | train loss -6.3235 | val loss na | dt 6.27ms | tok/sec 71817.54 | lr 3.93e-06
# iter (global) 17900: | train loss -6.3317 | val loss na | dt 6.50ms | tok/sec 69251.03 | lr 3.67e-06
# iter (global) 18000: | train loss -6.3397 | val loss na | dt 6.40ms | tok/sec 70366.36 | lr 3.42e-06
# iter (global) 18100: | train loss -6.3473 | val loss na | dt 7.20ms | tok/sec 62499.98 | lr 3.19e-06
# iter (global) 18200: | train loss -6.3547 | val loss na | dt 6.78ms | tok/sec 66381.91 | lr 2.97e-06
# iter (global) 18300: | train loss -6.3618 | val loss na | dt 6.46ms | tok/sec 69701.13 | lr 2.75e-06
# iter (global) 18400: | train loss -6.3686 | val loss na | dt 6.16ms | tok/sec 73029.09 | lr 2.56e-06
# iter (global) 18500: | train loss -6.3752 | val loss na | dt 6.29ms | tok/sec 71507.36 | lr 2.37e-06
# iter (global) 18600: | train loss -6.3814 | val loss na | dt 6.53ms | tok/sec 68952.50 | lr 2.19e-06
# iter (global) 18700: | train loss -6.3874 | val loss na | dt 6.48ms | tok/sec 69465.12 | lr 2.03e-06
# iter (global) 18800: | train loss -6.3932 | val loss na | dt 6.13ms | tok/sec 73455.41 | lr 1.88e-06
# iter (global) 18900: | train loss -6.3987 | val loss na | dt 6.33ms | tok/sec 71057.78 | lr 1.74e-06
# iter (global) 19000: | train loss -6.4039 | val loss na | dt 6.38ms | tok/sec 70545.20 | lr 1.61e-06
# iter (global) 19100: | train loss -6.4089 | val loss na | dt 6.51ms | tok/sec 69134.35 | lr 1.49e-06
# iter (global) 19200: | train loss -6.4137 | val loss na | dt 6.51ms | tok/sec 69144.48 | lr 1.39e-06
# iter (global) 19300: | train loss -6.4184 | val loss na | dt 6.51ms | tok/sec 69093.85 | lr 1.30e-06
# iter (global) 19400: | train loss -6.4228 | val loss na | dt 6.80ms | tok/sec 66179.41 | lr 1.22e-06
# iter (global) 19500: | train loss -6.4271 | val loss na | dt 7.00ms | tok/sec 64283.81 | lr 1.15e-06
# iter (global) 19600: | train loss -6.4314 | val loss na | dt 7.38ms | tok/sec 60967.66 | lr 1.10e-06
# iter (global) 19700: | train loss -6.4355 | val loss na | dt 6.65ms | tok/sec 67669.47 | lr 1.05e-06
# iter (global) 19800: | train loss -6.4397 | val loss na | dt 6.78ms | tok/sec 66374.91 | lr 1.02e-06
# iter (global) 19900: | train loss -6.4439 | val loss na | dt 6.43ms | tok/sec 70006.19 | lr 1.01e-06
# Total training time: 132.9s

# %%
# seed the model with just the viscous coefficients and look at ability to reproduce full trajectories
c_seed = c_full[:,:1]
v_seed = v_full[:,:1]
c_gen,v_gen = model.generate(c_seed,v_seed,max_new_tokens=40)

# %%
# show the results. the MV model learns to generalize
plt.rcParams['font.size'] = 10
plt.rcParams['font.family'] = 'Arial'

for i in range(11):
    if i==3 or i == 0:
        plt.plot(t[:40], v_full[i].detach().numpy().squeeze()[1:41])
        plt.scatter(t[:40], v_gen[i].detach().numpy().squeeze()[1:], marker='o')
    else:
        plt.plot(t[:40], v_full[i].detach().numpy().squeeze()[1:41],color='gray')
        plt.scatter(t[:40], v_gen[i].detach().numpy().squeeze()[1:], marker='x',color='gray')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# Out:
# (array([-1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ]),
#  [Text(0, -1.5, '−1.5'),
#   Text(0, -1.0, '−1.0'),
#   Text(0, -0.5, '−0.5'),
#   Text(0, 0.0, '0.0'),
#   Text(0, 0.5, '0.5'),
#   Text(0, 1.0, '1.0'),
#   Text(0, 1.5, '1.5'),
#   Text(0, 2.0, '2.0')])
